# %%
import scanpy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scanpy.external as sce
import anndata
import harmonypy as hm
import os
from scipy.sparse import csr_matrix #für die sparse matrix
import warnings
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", RuntimeWarning)
from scipy import stats
random_state=10
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-fgtphz_5 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor="white")
# Out:
# scanpy==1.10.2 anndata==0.10.8 umap==0.5.6 numpy==1.24.4 scipy==1.11.3 pandas==2.2.3 scikit-learn==1.3.1 statsmodels==0.14.0 igraph==0.11.6 pynndescent==0.5.13

# %%
# Ensure editable text in PDF exports
plt.rcParams['pdf.fonttype'] = 42

# %%
adata_CM=sc.read_h5ad('/data2/core-med1/nhadizad/nastaran/Xenotransplant/Cardiomyocytes/Cardiomyocytes stuff/CM 10/files v10/annotated_DEA_adata_v10.h5ad')

# %%
adata_vascular_EC=sc.read_h5ad("/data2/core-med1/nhadizad/nastaran/Xenotransplant/ECs/v2.1 results & data/data v2.1/annotated_DEA_adata2.h5ad")

# %%
adata_fibroblasts=sc.read_h5ad('/data2/core-med1/elindber/PROJECTS/20231020_el_Xenotransplant/results/20240220_el_Xenotransplant_BR_FB_PIG_2ndIT_ANNOTATED.h5ad')

# %%
adata_MPs_papio=sc.read_h5ad("/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/Immunecells_without_regress_out/FINAL_Objects_Annotated_Without_RO/NEWFINAL_Baboon_Macrophages_Annotated_Without_RO_250519.h5ad")

# %%
import matplotlib.pyplot as plt
import scanpy as sc

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression (replace with your gene name)
sc.pl.umap(
    adata_CM,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=3,                                 # dot size (same as before)
    cmap="viridis", 
    vmin=0,      # Set minimum value
    vmax=4,     # Set maximum value# your chosen colormap for a feature plot; e.g., "viridis", "magma"
    ax=ax,
    show=False
)

# Axis customization (as before)
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_Cardiomyocytes.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import scanpy as sc

# Create your custom colormap
dimplot_color = mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["#E5E5E5","#FF0000"])

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression
sc.pl.umap(
    adata_CM,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=3,                                 # dot size
    cmap=dimplot_color,                     # Use your custom colormap here
    vmin=0,                                 # Set minimum value
    vmax=6,                                 # Set maximum value
    ax=ax,
    show=False
)

# Axis customization
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_CM_papio_red.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import scanpy as sc

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression (replace with your gene name)
sc.pl.umap(
    adata_vascular_EC,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=3,                                 # dot size (same as before)
    cmap="viridis",                           # your chosen colormap for a feature plot; e.g., "viridis", "magma"
    vmin=0,      # Set minimum value
    vmax=4,     # Set maximum value# your chosen colormap for a feature plot; e.g., "viridis", "magma"
    ax=ax,
    show=False
)

# Axis customization (as before)
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_vascular_EC.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import scanpy as sc

# Create your custom colormap
dimplot_color = mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["#E5E5E5","#FF0000"])

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression
sc.pl.umap(
    adata_vascular_EC,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=6,                                 # dot size
    cmap=dimplot_color,                     # Use your custom colormap here
    vmin=0,                                 # Set minimum value
    vmax=6,                                 # Set maximum value
    ax=ax,
    show=False
)

# Axis customization
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_Vascular_papio_red.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import scanpy as sc

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression (replace with your gene name)
sc.pl.umap(
    adata_fibroblasts,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=3,                                 # dot size (same as before)
    cmap="viridis",                           # your chosen colormap for a feature plot; e.g., "viridis", "magma"
    vmin=0,      # Set minimum value
    vmax=4,     # Set maximum value# your chosen colormap for a feature plot; e.g., "viridis", "magma"
    ax=ax,
    show=False
)

# Axis customization (as before)
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_fibroblasts.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import scanpy as sc

# Create your custom colormap
dimplot_color = mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["#E5E5E5","#FF0000"])

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression
sc.pl.umap(
    adata_fibroblasts,
    color=["Sus_scrofa___HIF1A"],           # your feature gene
    frameon=False,
    size=7,                                 # dot size
    cmap=dimplot_color,                     # Use your custom colormap here
    vmin=0,                                 # Set minimum value
    vmax=6,                                 # Set maximum value
    ax=ax,
    show=False
)

# Axis customization
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_Fibroblasts_papio_red.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import scanpy as sc

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression (replace with your gene name)
sc.pl.umap(
    adata_MPs_papio,
    color=["Papio_anubis_HIF1A"],           # your feature gene
    frameon=False,
    size=3,                                 # dot size (same as before)
    cmap="RdBu",                           # your chosen colormap for a feature plot; e.g., "viridis", "magma"
    vmin=0,      # Set minimum value
    vmax=4,     # Set maximum value# your chosen colormap for a feature plot; e.g., "viridis", "magma"
    ax=ax,
    show=False
)

# Axis customization (as before)
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_MPs_papio.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import scanpy as sc

# Create your custom colormap
dimplot_color = mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["#E5E5E5","#FF0000"])

# Create high-resolution figure
fig, ax = plt.subplots(figsize=(3,3), dpi=300)

# UMAP feature plot for gene expression
sc.pl.umap(
    adata_MPs_papio,
    color=["Papio_anubis_HIF1A"],           # your feature gene
    frameon=False,
    size=7,                                 # dot size
    cmap=dimplot_color,                     # Use your custom colormap here
    vmin=0,                                 # Set minimum value
    vmax=6,                                 # Set maximum value
    ax=ax,
    show=False
)

# Axis customization
ax.set_xlabel('UMAP1', fontsize=16, loc='left')
ax.set_ylabel('UMAP2', fontsize=16, loc='bottom')
ax.tick_params(labelbottom=True, labelleft=True, labelsize=14)

plt.tight_layout()

# Save as high-quality PDF
pdf_folder = '/data2/core-med1/fibecker/fibecker/New_data_Xentransplantation/FINAL_whole_object_all_combined/Whole_object analysis/UMAPS_for_publication/Feature_Plot/'
pdf_name = 'FeaturePlot_HIF1A_Global_object_UMAP_MPs_papio_red.pdf'
output_path = pdf_folder + pdf_name
plt.savefig(output_path, format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

plt.show()
